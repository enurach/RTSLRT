# %%
import pandas as pd
import numpy as np
import random
import torch

# %%
anotation = pd.read_csv('annotations.csv')

# %%
anotation
# Out:
#                                 attachment_id      text  \
# 0        44e8d2a0-7e01-450b-90b0-beb7400d2c1e         Ё
# 1        df5b08f0-41d1-4572-889c-8b893e71069b         А
# 2        17f53df4-c467-4aff-9f48-20687b63d49a         Р
# 3        e3add916-c708-4339-ad98-7e2740be29e9         Е
# 4        bd7272ed-1850-48f1-a2a8-c8fed523dc37         Ч
# ...                                       ...       ...
# 20395  nodca88242-2bc7-4a77-9d14-103aa1dacbd6  no_event
# 20396  no7a7812b1-ae64-4402-9ebc-5b947edbd021  no_event
# 20397  no62a4df76-b48d-4f61-b6e8-bc4a1eb0cb61  no_event
# 20398  no388a3f7c-3594-4332-bc78-b5b53190301d  no_event
# 20399  no5393ec0c-85a4-4980-a2da-e84259050d83  no_event
#
#                                 user_id  height  width  length  train
# 0      185bd3a81d9d618518d10abebf0d17a8    1920   1080    76.0   True
# 1      185bd3a81d9d618518d10abebf0d17a8    1920   1080    40.0   True
# 2      185bd3a81d9d618518d10abebf0d17a8    1920   1080    57.0   True
# ...

# %%
unique_out = anotation['text'].unique()

# %%
unique_out
# Out:
# array(['Ё', 'А', 'Р', ..., 'время 11 часов', 'навсегда', 'no_event'],
#       dtype=object)

# %%
selected_out = random.sample(unique_out.tolist(), 200)

# %%
selected_out
# Out:
# ['вас',
#  'черный',
#  'благополучие',
#  'шутить',
#  'минута',
#  'терять',
#  'один',
#  'шесть',
#  'дорога',
#  'бежевый',
#  'страсть',
#  'зелёный',
#  'банкет',
#  'аккуратный',
#  'детский',
#  'нераскрашенный',
#  'лев',
#  'длинный',
#  'необходимый',
#  'ланч',
#  'Ы',
#  'разочарованный',
#  'рвеность',
#  'покраснеть',
#  'помочь',
#  'страшный',
#  'мудрый',
#  'копыто',
#  'упасть',
#  'образованный',
#  'воздух',
#  'зубы',
#  'презрение',
#  'водоплавающее',
#  'З',
#  'вечер',
#  'домогаться',
#  'миграция',
#  'рыдать',
#  'Золото',
#  'жена',
#  'панда',
#  'по часам',
#  'тёплый',
#  'потом',
#  'верблюд',
#  'непослушный',
#  'начало',
#  'Жарить',
#  'без',
#  'вдохновлять',
#  'амбициозный',
#  'или',
#  'собака',
#  'овца',
#  'подозревать',
#  'когда',
#  'лягушка',
#  'против',
#  'Привет!',
#  'мальчик',
#  'Ц',
#  'четыре тысячи',
#  'жираф',
#  'адаптивное поведение',
#  'вкус',
#  'смотреть',
#  'кусок',
#  'сколько',
#  'четыре',
#  'стыдно',
# ...

# %%
selected_out.remove('7:45')

# %%
selected_out.remove('время от 0 ночи до 12 дня')

# %%
selected_out.remove('кусок; тонкими слоями')

# %%
selected_out
# Out:
# ['вас',
#  'черный',
#  'благополучие',
#  'шутить',
#  'минута',
#  'терять',
#  'один',
#  'шесть',
#  'дорога',
#  'бежевый',
#  'страсть',
#  'зелёный',
#  'банкет',
#  'аккуратный',
#  'детский',
#  'нераскрашенный',
#  'лев',
#  'длинный',
#  'необходимый',
#  'ланч',
#  'Ы',
#  'разочарованный',
#  'рвеность',
#  'покраснеть',
#  'помочь',
#  'страшный',
#  'мудрый',
#  'копыто',
#  'упасть',
#  'образованный',
#  'воздух',
#  'зубы',
#  'презрение',
#  'водоплавающее',
#  'З',
#  'вечер',
#  'домогаться',
#  'миграция',
#  'рыдать',
#  'Золото',
#  'жена',
#  'панда',
#  'по часам',
#  'тёплый',
#  'потом',
#  'верблюд',
#  'непослушный',
#  'начало',
#  'Жарить',
#  'без',
#  'вдохновлять',
#  'амбициозный',
#  'или',
#  'собака',
#  'овца',
#  'подозревать',
#  'когда',
#  'лягушка',
#  'против',
#  'Привет!',
#  'мальчик',
#  'Ц',
#  'четыре тысячи',
#  'жираф',
#  'адаптивное поведение',
#  'вкус',
#  'смотреть',
#  'кусок',
#  'сколько',
#  'четыре',
#  'стыдно',
# ...

# %%
selected_anotation = anotation[anotation['text'].isin(selected_out)]

# %%
selected_anotation
# Out:
#                               attachment_id           text  \
# 5      eced728b-ec24-4f91-a967-7377542a23e6              Л
# 6      cf6845ac-9e02-49b4-8d2b-f56c789f973a              Ц
# 9      3f0389e8-fe70-41b0-806d-8c1aae3d20c1              З
# 15     06000f55-6f8e-404b-a01c-a32f4a384590              Ы
# 25     03737e2c-f912-493b-ad40-8320ee9fdf30              Ц
# ...                                     ...            ...
# 20280  4a1e509e-ace8-4454-9a55-2d25057606fd      между тем
# 20281  90125507-863d-4aae-b8de-a0a2c49c2d83         начало
# 20282  3306b18a-4524-4d1c-9b57-df2e7038cbc3       недавний
# 20287  835beacc-a3fa-4626-a441-46d011bcb699       недавний
# 20296  4eeeea02-df4c-4667-872e-8387ed31c32e  башенные часы
#
#                                 user_id  height  width  length  train
# 5      185bd3a81d9d618518d10abebf0d17a8    1920   1080    76.0   True
# 6      95af8e702c909eee7145c6dc1a3d756b    1280    720    51.0   True
# ...

# %%
(selected_anotation['train'] == False).sum()
# Out:
# 985

# %%
(selected_anotation['train'] == True).sum()
# Out:
# 2955

# %%
selected_anotation.to_csv('croped_anotation.csv', index=False)

# %%
selected_anotation = pd.read_csv('croped_anotation.csv')

# %%
selected_anotation[selected_anotation['length'] > 100]
# Out:
#                              attachment_id                  text  \
# 142   10bd1481-0e42-4ea3-8d5e-69a31db9c09d                гнездо
# 144   57d24c9d-efdc-41d2-babb-fc467f862d9e              населять
# 148   fac32d2a-2584-496c-a27e-a9b5a460fbda               верблюд
# 182   c5b694b3-872e-420e-a942-66b59c8a5c60              миграция
# 185   92f9057d-ff25-4f2b-b9b5-e12230b9a360              ползанье
# 192   56f6a259-7fdd-43cb-bbde-263929e03977                собака
# 211   aae3c396-0269-4808-89e3-e825deb69ad9              миграция
# 235   5b6baa62-6ef0-4b46-8f86-b5f044b132c7                вилять
# 237   f8043fa4-c27d-4613-86b3-00f6c31beb42              миграция
# 255   3970c163-b57f-4e08-9768-fea8992163ad              миграция
# 266   fa66f528-d827-403e-9ee3-d33ca0070d81                  ежик
# 285   78470ad3-1152-44bc-b373-778e783c55b2              миграция
# 337   2fca99bf-0d89-446c-b811-9b6ca778fc66              миграция
# ...

# %%
selected_anotation[selected_anotation['text'] == 'страдать']
# Out:
#                              attachment_id      text  \
# 831   6685f8fd-847d-4043-ab60-116e8e2d4320  страдать
# 873   2e67acd8-fe37-4dd3-bbe0-126ea1cecacd  страдать
# 895   2c6465b6-693a-4262-976d-2f277cf6203c  страдать
# 952   09592628-2040-4402-a631-a8eddc667f9a  страдать
# 972   8dee0545-5a17-4208-87e6-ae89229cdbde  страдать
# 1017  6f839c01-635a-4fb3-a36b-fe10f535dc45  страдать
# 1040  507bcd95-9216-4c2a-b819-2bfb69b41b54  страдать
# 1048  c18f5584-e371-463b-83a5-9ca1af32c372  страдать
# 1067  222f0827-6d6e-43dc-863a-04d1762d061c  страдать
# 1172  3d58743c-8287-4173-9a36-fd2bac31c503  страдать
# 1256  9eeafc0b-85eb-4476-977a-05ce5618cde4  страдать
# 1279  0ad27eac-be6c-41a6-896b-06ba70aba90a  страдать
# 1304  c1786977-0582-4135-8dd7-7d90ac215c55  страдать
# 1311  77778189-4156-4daa-a615-4df68c47047b  страдать
# 1334  7bd53862-f595-4747-b8c5-a4b4a502ce55  страдать
# 3241  881f4bf4-0944-470c-916d-f8ecbd0daf79  страдать
# 3279  bb9d26ab-64f2-42b3-872e-19994f31c9f7  страдать
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
encoder_classes = np.load('encoder_classes.npy', allow_pickle=True)

# %%
label_encoder.classes_ = encoder_classes

# %%
selected_anotation['text'] = label_encoder.fit_transform(selected_anotation['text'])
np.save('encoder_classes.npy', label_encoder.classes_)
# Out:
# /home/emasle/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/emasle/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
#encoder = LabelEncoder()
#encoder.classes_ = numpy.load('classes.npy')

# %%
selected_anotation['text'] = label_encoder.transform(selected_anotation['text'])
# Out:
# /home/emasle/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/emasle/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
selected_anotation
# Out:
#                              attachment_id  text  \
# 0     eced728b-ec24-4f91-a967-7377542a23e6     4
# 1     cf6845ac-9e02-49b4-8d2b-f56c789f973a    11
# 2     3f0389e8-fe70-41b0-806d-8c1aae3d20c1     1
# 3     06000f55-6f8e-404b-a01c-a32f4a384590    12
# 4     03737e2c-f912-493b-ad40-8320ee9fdf30    11
# ...                                    ...   ...
# 3935  4a1e509e-ace8-4454-9a55-2d25057606fd    99
# 3936  90125507-863d-4aae-b8de-a0a2c49c2d83   111
# 3937  3306b18a-4524-4d1c-9b57-df2e7038cbc3   112
# 3938  835beacc-a3fa-4626-a441-46d011bcb699   112
# 3939  4eeeea02-df4c-4667-872e-8387ed31c32e    19
#
#                                user_id  height  width  length  train
# 0     185bd3a81d9d618518d10abebf0d17a8    1920   1080    76.0   True
# 1     95af8e702c909eee7145c6dc1a3d756b    1280    720    51.0   True
# 2     185bd3a81d9d618518d10abebf0d17a8    1920   1080    80.0   True
# 3     185bd3a81d9d618518d10abebf0d17a8    1920   1080    70.0   True
# ...

# %%
selected_anotation.to_csv('croped_anotation.csv', index=False)
